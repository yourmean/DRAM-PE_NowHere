# %% [markdown]
# https://kaggle-kr.tistory.com/32<br>
# https://www.kaggle.com/code/ash316/eda-to-prediction-dietanic/notebook

# %% [markdown]
# # EDA To Prediction (DieTanic)

# %% [markdown]
# # Part1: Exploratory Data Analysis(EDA):

# %% [markdown]
# 1) Analysis of the features.<br>
# 2) Finding any relations or trends considering multiple features.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('titanic/train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 숫자형 데이터만 describe

data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Age, Cabin feature null값 다수 존재

data.isnull().sum() #checking for total null values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## How many Survived?

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

# ax[0]
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')

# ax[1]
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# ## Types Of Features

# %% [markdown]
# **Categorical Feature:**<br>
# 두 개 이상의 범주가 있는 변수이며, 범주별로 분류 가능한 feature. 값 사이에 순서를 지정하거나 정렬 불가<br>
# ex) Sex(성별), Embarked(승선/C,Q,S)<br>
# <br>
# **Ordinal Feature**<br>
# 두 개 이상의 범주가 있는 변수이며, 범주별로 분류 가능한 feature. 값 사이에 순서를 지정하거나 정렬 가능<br>
# ex) PClass(1, 2, 3)<br>
# <br>
# **Continous Feature**<br>
# 연속적인 수로 수량화가 가능한 변수<br>
# ex) Age(나이)

# %% [markdown]
# ## Analysing The Features

# %% [markdown]
# ## Sex - Categorical Feature

# %%
data.groupby(['Sex','Survived'])['Survived']

# %%
data.groupby(['Sex','Survived']).count()
# Out:
#                  PassengerId  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex    Survived
# female 0                  81      81    81   64     81     81      81    81
#        1                 233     233   233  197    233    233     233   233
# male   0                 468     468   468  360    468    468     468   468
#        1                 109     109   109   93    109    109     109   109
#
#                  Cabin  Embarked
# Sex    Survived
# female 0             6        81
#        1            91       231
# male   0            62       468
#        1            45       109

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

# ax[0]
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')

# ax[1]
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %% [markdown]
# ## Pclass - Ordinal Feature

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow2_col1 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow2_col2 {
#             background-color:  #90c866;
#             color:  #000000;
#         }    #T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow3_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow3_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2d" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2dlevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow0_col0" class="data row0 col0" >80</td>
#                         <td id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow0_col1" class="data row0 col1" >136</td>
#                         <td id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2dlevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow1_col0" class="data row1 col0" >97</td>
#                         <td id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow1_col1" class="data row1 col1" >87</td>
#                         <td id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2dlevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow2_col0" class="data row2 col0" >372</td>
#                         <td id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow2_col1" class="data row2 col1" >119</td>
#                         <td id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2dlevel0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow3_col0" class="data row3 col0" >549</td>
#                         <td id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow3_col1" class="data row3 col1" >342</td>
#                         <td id="T_7f24956e_3929_11ed_98a0_b4a9fc6c4b2drow3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

# ax[0]
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')

# ax[1]
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data[['Pclass','Survived']].groupby(['Pclass']).mean().plot.bar()

# %%
# 두 feature를 동시에 분석하는 것이 중요!
# Lets check survival rate with Sex and Pclass Together.

pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow1_col3 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow2_col0 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow2_col1 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow2_col2 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow2_col3 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow3_col0 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow3_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow3_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2d" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2dlevel0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2dlevel1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow0_col0" class="data row0 col0" >3</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow0_col1" class="data row0 col1" >6</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow0_col2" class="data row0 col2" >72</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2dlevel1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow1_col0" class="data row1 col0" >91</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow1_col1" class="data row1 col1" >70</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow1_col2" class="data row1 col2" >72</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2dlevel0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2dlevel1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow2_col0" class="data row2 col0" >77</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow2_col1" class="data row2 col1" >91</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow2_col2" class="data row2 col2" >300</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2dlevel1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow3_col0" class="data row3 col0" >45</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow3_col1" class="data row3 col1" >17</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow3_col2" class="data row3 col2" >47</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2dlevel0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2dlevel1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow4_col0" class="data row4 col0" >216</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow4_col1" class="data row4 col1" >184</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow4_col2" class="data row4 col2" >491</td>
#                         <td id="T_7f83dd70_3929_11ed_a77e_b4a9fc6c4b2drow4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
# factorplot: categorical value를 쉽게 분리 가능

sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %% [markdown]
# ## Age - Continous Feature

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

# ax[0]
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))

# ax[1]
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# * Pclass 등급이 낮아질수록(1 -> 2 -> 3) 아동 수가 증가함
# * Pclass와 상관 없이 아동 생존 수는 많음
# * Pclass 1의 20-50대 생존 가능성이 높고 특히 여자가 높음 (?)
# * 남성의 경우 나이가 들수록 생존 확률이 감소 (?)

# %%
# Name으로 Age를 추측할 수 있기 때문에 Age를 기반으로 Name의 Null값을 채우는 전략

data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations

# %%
data.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
data.Initial
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Initial, Length: 891, dtype: object

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style  type="text/css" >
#     #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col5 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col6 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col7 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col8 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col9 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col10 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col11 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col12 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col13 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col14 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col15 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col16 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col5 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col6 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col7 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col8 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col9 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col10 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col11 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col12 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col13 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col14 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col15 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow1_col16 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2d" ><thead>    <tr>        <th class="index_name level0" >Initial</th>        <th class="col_heading level0 col0" >Capt</th>        <th class="col_heading level0 col1" >Col</th>        <th class="col_heading level0 col2" >Countess</th>        <th class="col_heading level0 col3" >Don</th>        <th class="col_heading level0 col4" >Dr</th>        <th class="col_heading level0 col5" >Jonkheer</th>        <th class="col_heading level0 col6" >Lady</th>        <th class="col_heading level0 col7" >Major</th>        <th class="col_heading level0 col8" >Master</th>        <th class="col_heading level0 col9" >Miss</th>        <th class="col_heading level0 col10" >Mlle</th>        <th class="col_heading level0 col11" >Mme</th>        <th class="col_heading level0 col12" >Mr</th>        <th class="col_heading level0 col13" >Mrs</th>        <th class="col_heading level0 col14" >Ms</th>        <th class="col_heading level0 col15" >Rev</th>        <th class="col_heading level0 col16" >Sir</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2dlevel0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col2" class="data row0 col2" >1</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col3" class="data row0 col3" >0</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col4" class="data row0 col4" >1</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col5" class="data row0 col5" >0</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col6" class="data row0 col6" >1</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col7" class="data row0 col7" >0</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col8" class="data row0 col8" >0</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col9" class="data row0 col9" >182</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col10" class="data row0 col10" >2</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col11" class="data row0 col11" >1</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col12" class="data row0 col12" >0</td>
#                         <td id="T_a3d64a68_392b_11ed_8a39_b4a9fc6c4b2drow0_col13" class="data row0 col13" >125</td>
#                         <t

# %%
# data 오탈자 수정

data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],inplace=True)

# %%
data.groupby('Initial')['Age'].mean() #lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %% [markdown]
# ## Filling NaN Ages

# %%
## Assigning the NaN Values with the Ceil values of the mean ages

data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any() #So no null values left finally
# Out:
# False

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))

# ax[0]
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)

# ax[1]
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %% [markdown]
# * 아동(5세 이하) / 여자 / 노인(80세)의 생존이 높다.
# * 30-40대 범위에서 사망자가 제일 많았다.

# %%
sns.factorplot('Pclass','Survived',col='Initial',data=data)
plt.show()

# %% [markdown]
# ## Embarked(승선) - Categorical Value

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow0_col0 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow0_col1 {
#             background-color:  #d2e866;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow0_col2 {
#             background-color:  #f2f866;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow0_col3 {
#             background-color:  #d8ec66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow0_col4 {
#             background-color:  #e8f466;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow1_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow1_col1 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow1_col2 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow1_col3 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow1_col4 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow2_col0 {
#             background-color:  #e6f266;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow2_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow2_col2 {
#             background-color:  #eef666;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow2_col3 {
#             background-color:  #e8f466;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow2_col4 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow3_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow3_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow3_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow4_col1 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow4_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow4_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow4_col4 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow5_col0 {
#             background-color:  #e3f166;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow5_col1 {
#             background-color:  #e6f266;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow5_col2 {
#             background-color:  #ecf666;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow5_col3 {
#             background-color:  #f8fc66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow5_col4 {
#             background-color:  #ebf566;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow6_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow6_col1 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow6_col2 {
#             background-color:  #e4f266;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow6_col3 {
#             background-color:  #bede66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow6_col4 {
#             background-color:  #dbed66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow7_col0 {
#             background-color:  #edf666;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow7_col1 {
#             background-color:  #bdde66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow7_col2 {
#             background-color:  #d3e966;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow7_col3 {
#             background-color:  #dcee66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow7_col4 {
#             background-color:  #d1e866;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow8_col0 {
#             background-color:  #52a866;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow8_col1 {
#             background-color:  #dcee66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow8_col2 {
#             background-color:  #81c066;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow8_col3 {
#             background-color:  #b0d866;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow8_col4 {
#             background-color:  #9acc66;
#             color:  #000000;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow9_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow9_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow9_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow9_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2drow9_col4 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2d" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Sex</th>        <th class="col_heading level0 col0" colspan=2>female</th>        <th class="col_heading level0 col2" colspan=2>male</th>        <th class="col_heading level0 col4" >All</th>    </tr>    <tr>        <th class="blank" ></th>        <th class="index_name level1" >Survived</th>        <th class="col_heading level1 col0" >0</th>        <th class="col_heading level1 col1" >1</th>        <th class="col_heading level1 col2" >0</th>        <th class="col_heading level1 col3" >1</th>        <th class="col_heading level1 col4" ></th>    </tr>    <tr>        <th class="index_name level0" >Embarked</th>        <th class="index_name level1" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2dlevel0_row0" class="row_heading level0 row0" rowspan=3>C</th>
#                         <th id="T_ae45c4ca_392c_11ed_9eca_b4a9fc6c4b2dlevel1_row0" class="row_heading level1 row0" >1</th>
#                         <td id="T_ae45c4ca_392c_11ed_9

# %% [markdown]
# ## Chances for Survival by Port Of Embarkation

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))

# ax[0,0]
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')

# ax[0,1]
sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')

# ax[1,0]
sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')

# ax[1,1]
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %% [markdown]
# * S에서 탑승한 승객 대부분이 Pclass 3
# * C에서 탑승한 승객의 생존율이 높은데, 이는 Pclass 1 / Pclass 2 승객이 많기 때문

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()

# %% [markdown]
# * Pclass 1과 Pclass 2의 여성 생존 확률은 거의 1.0에 수렴
# * Port S의 Pclass 3의 생존율이 남녀 모두 매우 낮음

# %% [markdown]
# ## Filling Embarked NaN

# %%
# S가 가장 많으므로, S로 NaN값 대체

data['Embarked'].fillna('S',inplace=True)

# %%
data.Embarked.isnull().any()# Finally No NaN values
# Out:
# False

# %% [markdown]
# ## SibSip(함께 탑승한 형제 또는 배우자 수) - Discrete Feature

# %% [markdown]
# This feature represents whether a person is alone or with his family members.<br>
# <br>
# Sibling = brother, sister, stepbrother, stepsister<br>
# <br>
# Spouse = husband, wife

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow1_col0 {
#             background-color:  #c4e266;
#             color:  #000000;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow1_col1 {
#             background-color:  #77bb66;
#             color:  #000000;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow2_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow2_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow3_col0 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow3_col1 {
#             background-color:  #fbfd66;
#             color:  #000000;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow4_col0 {
#             background-color:  #f9fc66;
#             color:  #000000;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow4_col1 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow6_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2d" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow0_col0" class="data row0 col0" >398</td>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow0_col1" class="data row0 col1" >210</td>
#             </tr>
#             <tr>
#                         <th id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow1_col0" class="data row1 col0" >97</td>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow1_col1" class="data row1 col1" >112</td>
#             </tr>
#             <tr>
#                         <th id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow2_col0" class="data row2 col0" >15</td>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow2_col1" class="data row2 col1" >13</td>
#             </tr>
#             <tr>
#                         <th id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow3_col0" class="data row3 col0" >12</td>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow3_col1" class="data row3 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow4_col0" class="data row4 col0" >15</td>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow4_col1" class="data row4 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow5_col0" class="data row5 col0" >5</td>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2dlevel0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow6_col0" class="data row6 col0" >7</td>
#                         <td id="T_2bae0736_392e_11ed_962c_b4a9fc6c4b2drow6_col1" class="data row6 col1" >0</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))

# ax[0]
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')

# ax[1]
sns.factorplot('SibSp','Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp vs Survived')
# plt.close(2)
plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow1_col0 {
#             background-color:  #7bbd66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow1_col1 {
#             background-color:  #8ac466;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow1_col2 {
#             background-color:  #c6e266;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow2_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow2_col1 {
#             background-color:  #eef666;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow2_col2 {
#             background-color:  #f8fc66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow3_col0 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow3_col1 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow3_col2 {
#             background-color:  #fafc66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow4_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow4_col2 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow5_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow6_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow6_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }</style><table id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2d" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >SibSp</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow0_col0" class="data row0 col0" >137</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow0_col1" class="data row0 col1" >120</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow0_col2" class="data row0 col2" >351</td>
#             </tr>
#             <tr>
#                         <th id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow1_col0" class="data row1 col0" >71</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow1_col1" class="data row1 col1" >55</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow1_col2" class="data row1 col2" >83</td>
#             </tr>
#             <tr>
#                         <th id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow2_col0" class="data row2 col0" >5</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow2_col1" class="data row2 col1" >8</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow2_col2" class="data row2 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow3_col0" class="data row3 col0" >3</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow3_col1" class="data row3 col1" >1</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow3_col2" class="data row3 col2" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow4_col0" class="data row4 col0" >0</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow4_col1" class="data row4 col1" >0</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow4_col2" class="data row4 col2" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow5_col1" class="data row5 col1" >0</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2dlevel0_row6" class="row_heading level0 row6" >8</th>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow6_col0" class="data row6 col0" >0</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow6_col1" class="data row6 col1" >0</td>
#                         <td id="T_93a6e682_392e_11ed_9d2b_b4a9fc6c4b2drow6_col2" class="data row6 col2" >7</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# * 혼자 탑승하는 경우 생존율이 34.5%
# * 혼자보다는 1-2인 같이 탑승한 경우의 생존율이 더 높음
# * SibSp가 증가하면 그래프가 대략적으로 감소. 즉, 배에 가족이 있다면 나 자신을 먼저 구하는 것이 아니라 가족을 구하려고 한다는 것을 알 수 있음
# * 5-8인 가족의 생존율은 0% --> 5-8인 가족은 모두 Pclass 3 --> Pclass 3의 모든 대가족이 사망했음을 알 수 있음

# %% [markdown]
# ## Parch(함께 탑승한 부모 또는 자녀 수)

# %%
pd.crosstab(data.Parch,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow0_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow0_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow1_col0 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow1_col1 {
#             background-color:  #c2e066;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow1_col2 {
#             background-color:  #dbed66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow2_col0 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow2_col1 {
#             background-color:  #e1f066;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow2_col2 {
#             background-color:  #e3f166;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow3_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow3_col1 {
#             background-color:  #fcfe66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow3_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow4_col0 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow4_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow4_col2 {
#             background-color:  #fefe66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow5_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow5_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow5_col2 {
#             background-color:  #fdfe66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow6_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow6_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow6_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }</style><table id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2d" ><thead>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>    </tr>    <tr>        <th class="index_name level0" >Parch</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow0_col0" class="data row0 col0" >163</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow0_col1" class="data row0 col1" >134</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow0_col2" class="data row0 col2" >381</td>
#             </tr>
#             <tr>
#                         <th id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow1_col0" class="data row1 col0" >31</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow1_col1" class="data row1 col1" >32</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow1_col2" class="data row1 col2" >55</td>
#             </tr>
#             <tr>
#                         <th id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2dlevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow2_col0" class="data row2 col0" >21</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow2_col1" class="data row2 col1" >16</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow2_col2" class="data row2 col2" >43</td>
#             </tr>
#             <tr>
#                         <th id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2dlevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow3_col0" class="data row3 col0" >0</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow3_col1" class="data row3 col1" >2</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow3_col2" class="data row3 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2dlevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow4_col0" class="data row4 col0" >1</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow4_col1" class="data row4 col1" >0</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow4_col2" class="data row4 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2dlevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow5_col0" class="data row5 col0" >0</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow5_col1" class="data row5 col1" >0</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2dlevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow6_col0" class="data row6 col0" >0</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow6_col1" class="data row6 col1" >0</td>
#                         <td id="T_ef4b2242_392e_11ed_933d_b4a9fc6c4b2drow6_col2" class="data row6 col2" >1</td>
#             </tr>
#     </tbody></table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))

# ax[0]
sns.barplot('Parch','Survived',data=data,ax=ax[0])
ax[0].set_title('Parch vs Survived')

# ax[1]
sns.factorplot('Parch','Survived',data=data,ax=ax[1])
ax[1].set_title('Parch vs Survived')
# plt.close(2)
plt.show()

# %% [markdown]
# * 혼자보다는 1-2인 같이 탑승한 경우의 생존율이 더 높음. 그러나 숫자가 증가할수록 생존율은 감소
# * 배에 1-3명의 부모 또는 자녀가 있는 사람에게는 생존율이 높음. 혼자 있는 것 또는 4명 이상인 경우 생존율이 감소

# %% [markdown]
# ## Fare - Continous Feature

# %%
print('Highest Fare was:',data['Fare'].max())
print('Lowest Fare was:',data['Fare'].min())
print('Average Fare was:',data['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.2042079685746

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))

# ax[0]
sns.distplot(data[data['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')

# ax[1]
sns.distplot(data[data['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')

# ax[2]
sns.distplot(data[data['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %% [markdown]
# <중간 정리><br>
# <br>
# * Sex: 여성 생존율 > 남성 생존율
# * Pclass: 1 > 2 > 3
# * Age: 5-10세 어린이 생존율이 높음. 15-35세 사망자가 많음
# * Embarked: Pclass 1 승객의 대다수가 S이지만 C에서 생존율이 더 높음. Q의 승객은 모두 Pclass 3
# * Parch + SibSp: (1-2명의 형제자매 or 부모자녀) > (혼자 or 대가족)

# %% [markdown]
# ## Correlation Between The Features

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %% [markdown]
# Heatmap<br>
# <br>
# * 알파벳 or 문자열 간의 상관 관계를 알 수 없기 때문에 numeric feature만 비교 가능
# * 다중공선성(MultiColinearity): 두 feature의 상관 관계가 매우 높을 때, 이는 두 feature 모두 매우 유사한 정보를 포함하고 있으며 정보의 변동이 거의 없음을 의미 --> model 생성 및 train 시 시간/overfitting 문제를 해결하기 위해 하나의 중복 feature를 제거해야 한다.
# * 해당 user는 titanic feature의 상관 관계가 높지 않다고 주장 --> 모두 사용

# %% [markdown]
# # Part 2: Feature Engineering and Data Cleaning

# %% [markdown]
# (...making...)
