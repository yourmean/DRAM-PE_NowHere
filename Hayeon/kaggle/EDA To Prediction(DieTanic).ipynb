# %% [markdown]
# # Part1: Exploratory Data Analysis(EDA)

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data=pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.isnull().sum() # 전체 null 값 확인하기
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Age, Cabin, Embarked에 null 값이 있음.

# %% [markdown]
# ## How many Survived?

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %% [markdown]
# 350명(전체 중 38.4%)만 생존함.

# %% [markdown]
# ## Analysing The Features

# %% [markdown]
# Categorical Features: Sex, Embarked
#
# Ordinal Features in the dataset: PClass
#
# Continuous Feature: Age

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
pd.crosstab(data.Pclass,data.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_a7f98_row0_col0, #T_a7f98_row1_col1, #T_a7f98_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_a7f98_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_a7f98_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_a7f98_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_a7f98_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_a7f98_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_a7f98_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_a7f98_row3_col0, #T_a7f98_row3_col1, #T_a7f98_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a7f98">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_a7f98_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a7f98_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a7f98_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7f98_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a7f98_row0_col0" class="data row0 col0" >80</td>
#       <td id="T_a7f98_row0_col1" class="data row0 col1" >136</td>
#       <td id="T_a7f98_row0_col2" class="data row0 col2" >216</td>
#     </tr>
#     <tr>
#       <th id="T_a7f98_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a7f98_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_a7f98_row1_col1" class="data row1 col1" >87</td>
#       <td id="T_a7f98_row1_col2" class="data row1 col2" >184</td>
#     </tr>
#     <tr>
#       <th id="T_a7f98_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a7f98_row2_col0" class="data row2 col0" >372</td>
#       <td id="T_a7f98_row2_col1" class="data row2 col1" >119</td>
#       <td id="T_a7f98_row2_col2" class="data row2 col2" >491</td>
#     </tr>
#     <tr>
#       <th id="T_a7f98_level0_row3" class="row_heading level0 row3" >All</th>
#       <td id="T_a7f98_row3_col0" class="data row3 col0" >549</td>
#       <td id="T_a7f98_row3_col1" class="data row3 col1" >342</td>
#       <td id="T_a7f98_row3_col2" class="data row3 col2" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
plt.show()

# %%
pd.crosstab([data.Sex,data.Survived],data.Pclass,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_d7c7f_row0_col0, #T_d7c7f_row0_col1, #T_d7c7f_row0_col3, #T_d7c7f_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_d7c7f_row0_col2, #T_d7c7f_row1_col2 {
#   background-color: #f1f866;
#   color: #000000;
# }
# #T_d7c7f_row1_col0 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_d7c7f_row1_col1 {
#   background-color: #a3d166;
#   color: #000000;
# }
# #T_d7c7f_row1_col3 {
#   background-color: #cfe766;
#   color: #000000;
# }
# #T_d7c7f_row2_col0 {
#   background-color: #a7d366;
#   color: #000000;
# }
# #T_d7c7f_row2_col1, #T_d7c7f_row2_col3 {
#   background-color: #85c266;
#   color: #000000;
# }
# #T_d7c7f_row2_col2 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_d7c7f_row3_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_d7c7f_row3_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_d7c7f_row3_col3 {
#   background-color: #f7fb66;
#   color: #000000;
# }
# #T_d7c7f_row4_col0, #T_d7c7f_row4_col1, #T_d7c7f_row4_col2, #T_d7c7f_row4_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d7c7f">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_d7c7f_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_d7c7f_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_d7c7f_level0_col2" class="col_heading level0 col2" >3</th>
#       <th id="T_d7c7f_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="index_name level1" >Survived</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7c7f_level0_row0" class="row_heading level0 row0" rowspan="2">female</th>
#       <th id="T_d7c7f_level1_row0" class="row_heading level1 row0" >0</th>
#       <td id="T_d7c7f_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_d7c7f_row0_col1" class="data row0 col1" >6</td>
#       <td id="T_d7c7f_row0_col2" class="data row0 col2" >72</td>
#       <td id="T_d7c7f_row0_col3" class="data row0 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_d7c7f_level1_row1" class="row_heading level1 row1" >1</th>
#       <td id="T_d7c7f_row1_col0" class="data row1 col0" >91</td>
#       <td id="T_d7c7f_row1_col1" class="data row1 col1" >70</td>
#       <td id="T_d7c7f_row1_col2" class="data row1 col2" >72</td>
#       <td id="T_d7c7f_row1_col3" class="data row1 col3" >233</td>
#     </tr>
#     <tr>
#       <th id="T_d7c7f_level0_row2" class="row_heading level0 row2" rowspan="2">male</th>
#       <th id="T_d7c7f_level1_row2" class="row_heading level1 row2" >0</th>
#       <td id="T_d7c7f_row2_col0" class="data row2 col0" >77</td>
#       <td id="T_d7c7f_row2_col1" class="data row2 col1" >91</td>
#       <td id="T_d7c7f_row2_col2" class="data row2 col2" >300</td>
#       <td id="T_d7c7f_row2_col3" class="data row2 col3" >468</td>
#     </tr>
#     <tr>
#       <th id="T_d7c7f_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_d7c7f_row3_col0" class="data row3 col0" >45</td>
#       <td id="T_d7c7f_row3_col1" class="data row3 col1" >17</td>
#       <td id="T_d7c7f_row3_col2" class="data row3 col2" >47</td>
#       <td id="T_d7c7f_row3_col3" class="data row3 col3" >109</td>
#     </tr>
#     <tr>
#       <th id="T_d7c7f_level0_row4" class="row_heading level0 row4" >All</th>
#       <th id="T_d7c7f_level1_row4" class="row_heading level1 row4" ></th>
#       <td id="T_d7c7f_row4_col0" class="data row4 col0" >216</td>
#       <td id="T_d7c7f_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_d7c7f_row4_col2" class="data row4 col2" >491</td>
#       <td id="T_d7c7f_row4_col3" class="data row4 col3" >891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.factorplot('Pclass','Survived',hue='Sex',data=data)
plt.show()

# %%
print('Oldest Passenger was of:',data['Age'].max(),'Years')
print('Youngest Passenger was of:',data['Age'].min(),'Years')
print('Average Age on the ship:',data['Age'].mean(),'Years')
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.69911764705882 Years

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sns.violinplot("Pclass","Age", hue="Survived", data=data,split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))
sns.violinplot("Sex","Age", hue="Survived", data=data,split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))
plt.show()

# %% [markdown]
# ### Check the Name feature! (Miss, Mrs 등 호칭 추출하기)
#
# 정규표현식(Regular Expression) 사용

# %%
data['Initial']=0
for i in data:
    data['Initial']=data.Name.str.extract('([A-Za-z]+)\.') # using Regex(정규표현식)

# %%
data['Initial']
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Initial, Length: 891, dtype: object

# %%
data['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
pd.crosstab(data.Initial,data.Sex).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style type="text/css">
# #T_035d8_row0_col0, #T_035d8_row0_col1, #T_035d8_row0_col3, #T_035d8_row0_col4, #T_035d8_row0_col5, #T_035d8_row0_col7, #T_035d8_row0_col8, #T_035d8_row0_col12, #T_035d8_row0_col15, #T_035d8_row0_col16, #T_035d8_row1_col2, #T_035d8_row1_col6, #T_035d8_row1_col9, #T_035d8_row1_col10, #T_035d8_row1_col11, #T_035d8_row1_col13, #T_035d8_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_035d8_row0_col2, #T_035d8_row0_col6, #T_035d8_row0_col9, #T_035d8_row0_col10, #T_035d8_row0_col11, #T_035d8_row0_col13, #T_035d8_row0_col14, #T_035d8_row1_col0, #T_035d8_row1_col1, #T_035d8_row1_col3, #T_035d8_row1_col4, #T_035d8_row1_col5, #T_035d8_row1_col7, #T_035d8_row1_col8, #T_035d8_row1_col12, #T_035d8_row1_col15, #T_035d8_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_035d8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
#       <th id="T_035d8_level0_col0" class="col_heading level0 col0" >Capt</th>
#       <th id="T_035d8_level0_col1" class="col_heading level0 col1" >Col</th>
#       <th id="T_035d8_level0_col2" class="col_heading level0 col2" >Countess</th>
#       <th id="T_035d8_level0_col3" class="col_heading level0 col3" >Don</th>
#       <th id="T_035d8_level0_col4" class="col_heading level0 col4" >Dr</th>
#       <th id="T_035d8_level0_col5" class="col_heading level0 col5" >Jonkheer</th>
#       <th id="T_035d8_level0_col6" class="col_heading level0 col6" >Lady</th>
#       <th id="T_035d8_level0_col7" class="col_heading level0 col7" >Major</th>
#       <th id="T_035d8_level0_col8" class="col_heading level0 col8" >Master</th>
#       <th id="T_035d8_level0_col9" class="col_heading level0 col9" >Miss</th>
#       <th id="T_035d8_level0_col10" class="col_heading level0 col10" >Mlle</th>
#       <th id="T_035d8_level0_col11" class="col_heading level0 col11" >Mme</th>
#       <th id="T_035d8_level0_col12" class="col_heading level0 col12" >Mr</th>
#       <th id="T_035d8_level0_col13" class="col_heading level0 col13" >Mrs</th>
#       <th id="T_035d8_level0_col14" class="col_heading level0 col14" >Ms</th>
#       <th id="T_035d8_level0_col15" class="col_heading level0 col15" >Rev</th>
#       <th id="T_035d8_level0_col16" class="col_heading level0 col16" >Sir</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_035d8_level0_row0" class="row_heading level0 row0" >female</th>
#       <td id="T_035d8_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_035d8_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_035d8_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_035d8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_035d8_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_035d8_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_035d8_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_035d8_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_035d8_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_035d8_row0_col9" class="data row0 col9" >182</td>
#       <td id="T_035d8_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_035d8_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_035d8_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_035d8_row0_col13" class="data row0 col13" >125</td>
#       <td id="T_035d8_row0_col14" class="data row0 col14" >1</td>
#       <td id="T_035d8_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_035d8_row0_col16" class="data row0 col16" >0</td>
#     </tr>
#     <tr>
#       <th id="T_035d8_level0_row1" class="row_heading level0 row1" >male</th>
#       <td id="T_035d8_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_035d8_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_035d8_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_035d8_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_035d8_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_035d8_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_035d8_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_035d8_row1_col7" class="data row1 col7" >2</td>
#       <td id="T_035d8_row1_col8" class="data row1 col8" >40</td>
#       <td id="T_035d8_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_035d8_row1_col10" class="data row1 col10" >0</td>
#       <td id="T_035d8_row1_col11" class="data row1 col11" >0</td>
#       <td id="T_035d8_row1_col12" class="data row1 col12" >517</td>
#       <td id="T_035d8_row1_col13" class="data row1 col13" >0</td>
#       <td id="T_035d8_row1_col14" class="data row1 col14" >0</td>
#       <td id="T_035d8_row1_col15" class="data row1 col15" >6</td>
#       <td id="T_035d8_row1_col16" class="data row1 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
data['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr'],
                        inplace=True)

# %%
data.groupby('Initial')['Age'].mean() #lets check the average age by Initials
# Out:
# Initial
# Master     4.574167
# Miss      21.860000
# Mr        32.739609
# Mrs       35.981818
# Other     45.888889
# Name: Age, dtype: float64

# %% [markdown]
# ### Filling NaN Ages

# %%
## Assigning the NaN Values with the Ceil values of the mean ages

data.loc[(data.Age.isnull())&(data.Initial=='Mr'),'Age']=33
data.loc[(data.Age.isnull())&(data.Initial=='Mrs'),'Age']=36
data.loc[(data.Age.isnull())&(data.Initial=='Master'),'Age']=5
data.loc[(data.Age.isnull())&(data.Initial=='Miss'),'Age']=22
data.loc[(data.Age.isnull())&(data.Initial=='Other'),'Age']=46

# %%
data.Age.isnull().any() #So no null values left finally
# Out:
# False

# %% [markdown]
# 최종적으로 Null 값 모두 대체됨.

# %%
f,ax=plt.subplots(1,2,figsize=(20,10))
data[data['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))
ax[0].set_xticks(x1)
data[data['Survived']==1].Age.plot.hist(ax=ax[1],color='green',bins=20,edgecolor='black')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
sns.factorplot('Pclass','Survived',col='Initial',data=data)
plt.show()

# %%
pd.crosstab([data.Embarked,data.Pclass],[data.Sex,data.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_993aa_row0_col0, #T_993aa_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_993aa_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_993aa_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_993aa_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_993aa_row0_col4, #T_993aa_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_993aa_row1_col0, #T_993aa_row3_col0, #T_993aa_row3_col1, #T_993aa_row3_col2, #T_993aa_row3_col3, #T_993aa_row3_col4, #T_993aa_row4_col0, #T_993aa_row4_col2, #T_993aa_row4_col3, #T_993aa_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_993aa_row1_col1, #T_993aa_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_993aa_row1_col3, #T_993aa_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_993aa_row2_col0, #T_993aa_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_993aa_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_993aa_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_993aa_row2_col4, #T_993aa_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_993aa_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_993aa_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_993aa_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_993aa_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_993aa_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_993aa_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_993aa_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_993aa_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_993aa_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_993aa_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_993aa_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_993aa_row7_col3, #T_993aa_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_993aa_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_993aa_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_993aa_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_993aa_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_993aa_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_993aa_row9_col0, #T_993aa_row9_col1, #T_993aa_row9_col2, #T_993aa_row9_col3, #T_993aa_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_993aa">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_993aa_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_993aa_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_993aa_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_993aa_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_993aa_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_993aa_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_993aa_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_993aa_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_993aa_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_993aa_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_993aa_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_993aa_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_993aa_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_993aa_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_993aa_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_993aa_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_993aa_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_993aa_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_993aa_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_993aa_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_993aa_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_993aa_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_993aa_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_993aa_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_993aa_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_993aa_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_993aa_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_993aa_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_993aa_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_993aa_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_993aa_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_993aa_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_993aa_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_993aa_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_993aa_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_993aa_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_993aa_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_993aa_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_993aa_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_993aa_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_993aa_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_993aa_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_993aa_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_993aa_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_993aa_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_993aa_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_993aa_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_993aa_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_993aa_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_993aa_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_993aa_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_993aa_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_993aa_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_993aa_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_993aa_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_993aa_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_993aa_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_993aa_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_993aa_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_993aa_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_993aa_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_993aa_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_993aa_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_993aa_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_993aa_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_993aa_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_993aa_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_993aa_row9_col0" class="data row9 col0" >81</td>
#       <t

# %%
sns.factorplot('Embarked','Survived',data=data)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
f,ax=plt.subplots(2,2,figsize=(20,15))
sns.countplot('Embarked',data=data,ax=ax[0,0])
ax[0,0].set_title('No. Of Passengers Boarded')
sns.countplot('Embarked',hue='Sex',data=data,ax=ax[0,1])
ax[0,1].set_title('Male-Female Split for Embarked')
sns.countplot('Embarked',hue='Survived',data=data,ax=ax[1,0])
ax[1,0].set_title('Embarked vs Survived')
sns.countplot('Embarked',hue='Pclass',data=data,ax=ax[1,1])
ax[1,1].set_title('Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2,hspace=0.5)
plt.show()

# %%
sns.factorplot('Pclass','Survived',hue='Sex',col='Embarked',data=data)
plt.show()

# %% [markdown]
# #### Filling Embarked NaN

# %%
data['Embarked'].fillna('S',inplace=True)

# %%
data.Embarked.isnull().any()# Finally No NaN values
# Out:
# False

# %% [markdown]
# #### SibSip Feature

# %%
pd.crosstab([data.SibSp],data.Survived).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_f1770_row0_col0, #T_f1770_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_f1770_row1_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# #T_f1770_row1_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_f1770_row2_col0, #T_f1770_row4_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_f1770_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_f1770_row3_col0, #T_f1770_row3_col1 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_f1770_row4_col1 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_f1770_row5_col0, #T_f1770_row5_col1, #T_f1770_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_f1770_row6_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_f1770">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_f1770_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f1770_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1770_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1770_row0_col0" class="data row0 col0" >398</td>
#       <td id="T_f1770_row0_col1" class="data row0 col1" >210</td>
#     </tr>
#     <tr>
#       <th id="T_f1770_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f1770_row1_col0" class="data row1 col0" >97</td>
#       <td id="T_f1770_row1_col1" class="data row1 col1" >112</td>
#     </tr>
#     <tr>
#       <th id="T_f1770_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f1770_row2_col0" class="data row2 col0" >15</td>
#       <td id="T_f1770_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_f1770_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f1770_row3_col0" class="data row3 col0" >12</td>
#       <td id="T_f1770_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_f1770_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f1770_row4_col0" class="data row4 col0" >15</td>
#       <td id="T_f1770_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f1770_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f1770_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_f1770_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f1770_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_f1770_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_f1770_row6_col1" class="data row6 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
f,ax=plt.subplots(1,2,figsize=(20,8))
sns.barplot('SibSp','Survived',data=data,ax=ax[0])
ax[0].set_title('SibSp vs Survived')
sns.factorplot('SibSp','Survived',data=data,ax=ax[1])
ax[1].set_title('SibSp vs Survived')
plt.close(2)
plt.show()

# %%
pd.crosstab(data.SibSp,data.Pclass).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_c8009_row0_col0, #T_c8009_row0_col1, #T_c8009_row0_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_c8009_row1_col0 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_c8009_row1_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_c8009_row1_col2 {
#   background-color: #c6e266;
#   color: #000000;
# }
# #T_c8009_row2_col0, #T_c8009_row4_col2 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_c8009_row2_col1 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_c8009_row2_col2 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_c8009_row3_col0, #T_c8009_row3_col2 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_c8009_row3_col1 {
#   background-color: #fdfe66;
#   color: #000000;
# }
# #T_c8009_row4_col0, #T_c8009_row4_col1, #T_c8009_row5_col0, #T_c8009_row5_col1, #T_c8009_row5_col2, #T_c8009_row6_col0, #T_c8009_row6_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_c8009_row6_col2 {
#   background-color: #fefe66;
#   color: #000000;
# }
# </style>
# <table id="T_c8009">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Pclass</th>
#       <th id="T_c8009_level0_col0" class="col_heading level0 col0" >1</th>
#       <th id="T_c8009_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_c8009_level0_col2" class="col_heading level0 col2" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >SibSp</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8009_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8009_row0_col0" class="data row0 col0" >137</td>
#       <td id="T_c8009_row0_col1" class="data row0 col1" >120</td>
#       <td id="T_c8009_row0_col2" class="data row0 col2" >351</td>
#     </tr>
#     <tr>
#       <th id="T_c8009_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8009_row1_col0" class="data row1 col0" >71</td>
#       <td id="T_c8009_row1_col1" class="data row1 col1" >55</td>
#       <td id="T_c8009_row1_col2" class="data row1 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_c8009_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8009_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_c8009_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_c8009_row2_col2" class="data row2 col2" >15</td>
#     </tr>
#     <tr>
#       <th id="T_c8009_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8009_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_c8009_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_c8009_row3_col2" class="data row3 col2" >12</td>
#     </tr>
#     <tr>
#       <th id="T_c8009_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8009_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_c8009_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_c8009_row4_col2" class="data row4 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_c8009_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c8009_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_c8009_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_c8009_row5_col2" class="data row5 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_c8009_level0_row6" class="row_heading level0 row6" >8</th>
#       <td id="T_c8009_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_c8009_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_c8009_row6_col2" class="data row6 col2" >7</td>
#     </tr>
#   </tbody>
# </table>
